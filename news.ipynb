# %%
# Check dataframe structure
import dask.dataframe as dd

dask_df = dd.read_csv('~/Downloads/news.csv')
dask_df
# Out:
# Dask DataFrame Structure:
#                Unnamed: 0      ID Content Summary Dataset
# npartitions=59
#                     int64  object  object  object  object
#                       ...     ...     ...     ...     ...
# ...                   ...     ...     ...     ...     ...
#                       ...     ...     ...     ...     ...
#                       ...     ...     ...     ...     ...
# Dask Name: read-csv, 59 tasks

# %%
# Create a dask client if you want to use the dashboard
from dask.distributed import Client

client = Client()
client.restart()
# Out:
# /Users/SongYoungOh/opt/anaconda3/lib/python3.9/site-packages/distributed/node.py:180: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 58948 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:58949' processes=5 threads=10, memory=16.00 GiB>
